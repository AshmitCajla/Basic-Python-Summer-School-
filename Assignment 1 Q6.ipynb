# %%
import random as r
a =(r.sample(range(100,900), 100))
print(a)
# Out:
# [528, 180, 149, 444, 782, 592, 442, 394, 185, 836, 736, 574, 889, 293, 112, 665, 492, 776, 821, 342, 538, 217, 500, 242, 684, 345, 533, 535, 867, 748, 290, 218, 671, 658, 294, 167, 838, 378, 688, 524, 563, 435, 222, 642, 637, 384, 335, 434, 513, 223, 274, 752, 370, 216, 153, 556, 617, 315, 537, 515, 269, 422, 433, 451, 454, 251, 236, 348, 194, 591, 110, 440, 309, 117, 428, 569, 351, 753, 634, 401, 647, 735, 507, 412, 192, 886, 458, 544, 699, 326, 131, 481, 582, 599, 649, 804, 244, 779, 338, 791]

# %%
eVn = []
oDd = []
for i in a:
    if i % 2 == 0:
        eVn.append(i)
    else:
        oDd.append(i)
print ('Even Numbers :', eVn)
print ('Odd Numbers :', oDd)
# Out:
# Even Numbers : [528, 180, 444, 782, 592, 442, 394, 836, 736, 574, 112, 492, 776, 342, 538, 500, 242, 684, 748, 290, 218, 658, 294, 838, 378, 688, 524, 222, 642, 384, 434, 274, 752, 370, 216, 556, 422, 454, 236, 348, 194, 110, 440, 428, 634, 412, 192, 886, 458, 544, 326, 582, 804, 244, 338]
# Odd Numbers : [149, 185, 889, 293, 665, 821, 217, 345, 533, 535, 867, 671, 167, 563, 435, 637, 335, 513, 223, 153, 617, 315, 537, 515, 269, 433, 451, 251, 591, 309, 117, 569, 351, 753, 401, 647, 735, 507, 699, 131, 481, 599, 649, 779, 791]

# %%
for i in a:
    def IsPrime(i):
        if i in range(2, i//2 + 1):
            if i%n==0:
# Out:
# Prime Numbers : []

# %%
pRm = []
NonpRm = []
for i in a:
    c = 0
    for j in range(1,i):
        if i % j == 0:
            pRm.append(i)
        else:
            NonpRm.append(i)
print ('Prime Numbers :', pRm)
# Out:
# Prime Numbers : [528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 528, 180, 180, 180, 180, 180, 180, 180, 180, 180, 180, 180, 180, 180, 180, 180, 180, 180, 149, 444, 444, 444, 444, 444, 444, 444, 444, 444, 444, 444, 782, 782, 782, 782, 782, 782, 782, 592, 592, 592, 592, 592, 592, 592, 592, 592, 442, 442, 442, 442, 442, 442, 442, 394, 394, 394, 185, 185, 185, 836, 836, 836, 836, 836, 836, 836, 836, 836, 836, 836, 736, 736, 736, 736, 736, 736, 736, 736, 736, 736, 736, 574, 574, 574, 574, 574, 574, 574, 889, 889, 889, 293, 112, 112, 112, 112, 112, 112, 112, 112, 112, 665, 665, 665, 665, 665, 665, 665, 492, 492, 492, 492, 492, 492, 492, 492, 492, 492, 492, 776, 776, 776, 776, 776, 776, 776, 821, 342, 342, 342, 342, 342, 342, 342, 342, 342, 342, 342, 538, 538, 538, 217, 217, 217, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 500, 242, 242, 242, 242, 242, 684, 684, 684, 684, 684, 684, 684, 684, 684, 684, 684, 684, 684, 684, 684, 684, 684, 345, 3
# ...
